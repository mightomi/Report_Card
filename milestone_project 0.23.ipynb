# %%
import pandas as pd  # all imports should be here
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('https://docs.google.com/spreadsheets/d/1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc/export?format=csv&id=1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc&gid=0',index_col=0,)
data2 = pd.read_csv('https://docs.google.com/spreadsheets/d/1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc/export?format=csv&id=1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc&gid=2076733987',index_col=0,)

# reading data from google doc spreadsheet 
# link for july datasheet below 
# https://docs.google.com/spreadsheets/d/1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc/export?format=csv&id=1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc&gid=0
# link for august datasheet below
# https://docs.google.com/spreadsheets/d/1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc/export?format=csv&id=1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc&gid=2076733987

data = data2
#data = pd.concat([data1, data2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357 entries, 0 to 0
# Data columns (total 9 columns):
# Task               357 non-null object
# Date               357 non-null object
# Module             357 non-null object
# Type               357 non-null object
# Student            357 non-null object
# Late Submission    357 non-null int64
# Points             357 non-null float64
# Total              357 non-null int64
# Task Winner        357 non-null int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 27.9+ KB

# %% [markdown]
# ### Cleaning data set

# %%
data["Student"].fillna("Swaastik",inplace=True)  # few empty blocks is actually me
data["Student"].replace("Swaastik","Swaastick",inplace=True)  

mask=data["Student"]!="Nitish"                   # removing sir
data=data[mask]

# %%
data.reset_index(inplace=True)  # giving index to data set
#data.drop([0],inplace=True)     # the first row contains nothing so removing it
data.dropna(inplace=True)
data=data.iloc[:,:10]           # Removing all unnessary columns after Task Winner if any
# Out:
# C:\Users\Swastik\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data # cleaner data-set
# Out:
#      id               Task                 Date            Module  \
# 0     0        AjKyaUkhada  2019-08-01 13:26:57            Ritual
# 1     0        AjKyaUkhada  2019-08-01 14:40:42            Ritual
# 2     0        AjKyaUkhada  2019-08-01 14:44:34            Ritual
# 3     0        AjKyaUkhada  2019-08-01 14:47:05            Ritual
# 4     0        AjKyaUkhada  2019-08-01 14:48:11            Ritual
# 5     0        AjKyaUkhada  2019-08-01 15:05:13            Ritual
# 6     0        AjKyaUkhada  2019-08-01 15:55:48            Ritual
# 7     0        AjKyaUkhada  2019-08-01 16:08:05            Ritual
# 8     0        AjKyaUkhada  2019-08-01 16:16:30            Ritual
# 9     0        AjKyaUkhada  2019-08-01 16:17:01            Ritual
# 10    0        AjKyaUkhada  2019-08-01 17:05:15            Ritual
# 11    0        AjKyaUkhada  2019-08-01 17:29:07            Ritual
# 12    0        AjKyaUkhada  2019-08-01 18:01:53            Ritual
# 13    0        AjKyaUkhada  2019-08-01 18:21:29            Ritual
# 14    0        AjKyaUkhada  2019-08-01 18:29:24            Ritual
# 15    0        AjKyaUkhada  2019-08-01 19:52:40            Ritual
# 16    5       Video Resume             8/1/2019  Profile Building
# 17    5       Video Resume             8/1/2019  Profile Building
# 18    5       Video Resume             8/1/2019  Profile Building
# 19    5       Video Resume             8/1/2019  Profile Building
# 20    5       Video Resume             8/1/2019  Profile Building
# 21    5       Video Resume             8/1/2019  Profile Building
# 22    5       Video Resume             8/1/2019  Profile Building
# 23    5       Video Resume             8/1/2019  Profile Building
# 24    5       Video Resume             8/1/2019  Profile Building
# 25    5       Video Resume             8/1/2019  Profile Building
# 26    5       Video Resume             8/1/2019  Profile Building
# 27    5       Video Resume             8/1/2019  Profile Building
# 28    5       Video Resume             8/1/2019  Profile Building
# 29    5       Video Resume             8/1/2019  Profile Building
# ..   ..                ...                  ...               ...
# 327   0        AjKyaUkhada  2019-08-14 14:37:42            Ritual
# 328  10     PPT Submission           14/08/2019  Machine Learning
# 329  10     PPT Submission           14/08/2019  Machine Learning
# 330  10     PPT Submission           14/08/2019  Machine Learning
# 331  10     PPT Submission           14/08/2019  Machine Learning
# 332  10     PPT Submission           14/08/2019  Machine Learning
# 333  10     PPT Submission           14/08/2019  Machine Learning
# 334  10     PPT Submission           14/08/2019  Machine Learning
# 335  10     PPT Submission           14/08/2019  Machine Learning
# 336  10     PPT Submission           14/08/2019  Machine Learning
# 337  10     PPT Submission           14/08/2019  Machine Learning
# 338  10     PPT Submission           14/08/2019  Machine Learning
# 339  10     PPT Submission           14/08/2019  Machine Learning
# 340  10     PPT Submission           14/08/2019  Machine Learning
# 341  10     PPT Submission           14/08/2019  Machine Learning
# 342  10     PPT Submission           14/08/2019  Machine Learning
# 343   0        AjKyaUkhada  2019-08-14 14:55:44            Ritual
# 344   0        AjKyaUkhada  2019-08-14 15:04:08            Ritual
# 345   0        AjKyaUkhada  2019-08-14 15:06:00            Ritual
# 346   0        AjKyaUkhada  2019-08-14 16:36:17            Ritual
# 347   0  Knowledge Sharing  2019-08-14 16:38:37            Ritual
# 348   0        AjKyaUkhada  2019-08-14 16:41:52            Ritual
# 349   0        AjKyaUkhada  2019-08-14 17:07:02            Ritual
# 350   0  Knowledge Sharing  2019-08-14 17:17:39            Ritual
# 351   0        AjKyaUkhada  2019-08-14 17:47:59            Ritual
# 352   0        AjKyaUkhada  2019-08-14 18:16:44            Ritual
# 353   0        AjKyaUkhada  2019-08-14 18:17:20            Ritual
# 354   0        AjKyaUkhada  2019-08-14 18:17:53            Ritual
# 355   0        AjKyaUkhada  2019-08-14 19:00:16            Ritual
# 356   0        AjKyaUkhada  2019-08-14 19:29:00            Ritual
#
#                                            Type       Student  \
# 0                                   Consistency        Sonali
# 1                                   Consistency     Chandrima
# 2                                   Consistency       Purbita
# 3                                   Consistency         Kunal
# 4                                   Consistency       Kaushal
# 5                                   Consistency         Durga
# 6                                   Consistency      Ujjainee
# 7                                   Consistency         Dipam
# 8                                   Consistency  Siddhishikha
# 9                                   Consistency       Surabhi
# 10                                  Consistency     Swaastick
# 11                                  Consistency       Sharika
# 12                                  Consistency        Apurwa
# 13                                  Consistency        Shakib
# 14                                  Consistency        Vishal
# 15                                  Consistency         Wrick
# 16   Creativity,Communication,Intent,Confidence     Chandrima
# 17   Creativity,Communication,Intent,Confidence         Dipam
# 18   Creativity,Communication,Intent,Confidence         Durga
# 19   Creativity,Communication,Intent,Confidence       Kaushal
# 20   Creativity,Communication,Intent,Confidence          Arya
# 21   Creativity,Communication,Intent,Confidence         Kunal
# 22   Creativity,Communication,Intent,Confidence       Purbita
# 23   Creativity,Communication,Intent,Confidence       Roumyak
# 24   Creativity,Communication,Intent,Confidence        Shakib
# 25   Creativity,Communication,Intent,Confidence      Shantanu
# 26   Creativity,Communication,Intent,Confidence       Sharika
# 27   Creativity,Communication,Intent,Confidence        Sonali
# 28   Creativity,Communication,Intent,Confidence       Surabhi
# 29   Creativity,Communication,Intent,Confidence  Siddhishikha
# ..                                          ...           ...
# 327                                 Consistency       Purbita
# 328                                   Diligence          Arya
# 329                                   Diligence         Kunal
# 330                                   Diligence       Prasoon
# 331                                   Diligence       Purbita
# 332                                   Diligence       Roumyak
# 333                                   Diligence        Shakib
# 334                                   Diligence      Shantanu
# 335                                   Diligence       Sharika
# 336                                   Diligence        Sonali
# 337                                   Diligence       Surabhi
# 338                                   Diligence  Siddhishikha
# 339                                   Diligence     Swaastick
# 340                                   Diligence        Apurwa
# 341                                   Diligence      Ujjainee
# 342                                   Diligence        Vishal
# 343                                 Consistency         Kunal
# 344                                 Consistency         Dipam
# 345                                 Consistency       Surabhi
# 346                                 Consistency         Durga
# 347                       Consistency,Curiosity       Surabhi
# 348                                 Consistency       Kaushal
# 349                                 Consistency  Siddhishikha
# 350                       Consistency,Curiosity         Dipam
# 351                                 Consistency      Shantanu
# 352                                 Consistency        Shakib
# 353                                 Consistency     Chandrima
# 354                                 Consistency       Sharika
# 355                                 Consistency        Sonali
# 356                                 Consistency        Vishal
#
#      Late Submission  Points  Total  Task Winner  Date_day
# 0                  0     2.0      2            0         1
# 1                  0     2.0      2            0         1
# 2                  0     2.0      2            0         1
# 3                  0     2.0      2            0         1
# 4                  0     2.0      2            0         1
# 5                  0     2.0      2            0         1
# 6                  0     2.0      2            0         1
# 7                  0     2.0      2            0         1
# 8                  0     2.0      2            0         1
# 9                  0     2.0      2            0         1
# 10                 0     2.0      2            0         1
# 11                 0     2.0      2            0         1
# 12                 0     2.0      2            0         1
# 13                 0     2.0      2            0         1
# 14                 0     2.0      2            0         1
# 15                 0     2.0      2            0         1
# 16                 0    16.5     20            0         1
# 17                 0    14.0     20            0         1
# 18                 0    16.5     20            0         1
# 19                 1    16.5     20            0         1
# 20                 1    18.5     20            0         1
# 21                 0    20.0     20            0         1
# 22                 0    18.0     20            0         1
# 23                 0    20.0     20            1         1
# 24                 0    17.5     20            0         1
# 25                 0    20.0     20            1         1
# 26                 1    20.0     20            0         1
# 27                 1    16.5     20            0         1
# 28                 0    20.0     20            1         1
# 29                 0    16.0     20            0         1
# ..               ...     ...    ...          ...       ...
# 327                0     2.0      2            0        14
# 328                1     5.0      5            0         8
# 329                1     5.0      5            0         8
# 330                1     5.0      5            0         8
# 331                1     5.0      5            1         8
# 332                1     5.0      5            0         8
# 333                1     5.0      5            0         8
# 334                0     5.0      5            0         8
# 335                0     5.0      5            1         8
# 336                0     5.0      5            0         8
# 337                0     5.0      5            0         8
# 338                0     5.0      5            0         8
# 339                1     5.0      5            0         8
# 340                0     5.0      5            1         8
# 341                0     5.0      5            0         8
# 342                0     5.0      5            1         8
# 343                0     2.0      2            0        14
# 344                0     2.0      2            0        14
# 345                0     2.0      2            0        14
# 346                0     2.0      2            0        14
# 347                0     2.0      2            0        14
# 348                0     2.0      2            0        14
# 349                0     2.0      2            0        14
# 350                0     2.0      2            0        14
# 351                0     2.0      2            0        14
# 352                0     2.0      2            0        14
# 353                0     2.0      2            0        14
# 354                0     2.0      2            0        14
# 355                0     2.0      2            0        14
# 356                0     2.0      2            0        14
#
# [357 rows x 11 columns]

# %% [markdown]
# #### cleaning date

# %%
date_day=[]
date_month=[]
date_year=[]

for i in range(data.shape[0]):
    
    pos=data["Date"][i].find("/")
    
    if(len(data["Date"][i])>=18):                     # 2019-08-01 14:40:42
        #data["Date"][i]=data["Date"][i][:10]
        date_day.append(int(data["Date"][i][8:10]))
        date_month.append(int(data["Date"][i][5:7]))
        date_year.append(int(data["Date"][i][:4]))
        
    if(len(data["Date"][i])<18):  
        
        if( (int(data["Date"][i][pos+1:-5]))>12 or ( (len(data["Date"][i][pos+1:-5])==2) and (data["Date"][i][pos+1:-5][0]=="0") )  ):    # 14/08/2019
            pos=data["Date"][i].find("/")
            date_day.append(int(data["Date"][i][:pos]))
            date_month.append(int(data["Date"][i][pos+1:-5]))
            date_year.append(int(data["Date"][i][-4:]))
        
        else:
            pos=data["Date"][i].find("/")                     # 8/1/2019
            date_month.append(int(data["Date"][i][:pos]))
            date_day.append(int(data["Date"][i][pos+1:-5]))
            date_year.append(int(data["Date"][i][-4:]))   

data["Date_day"]=date_day
data["Date_month"]=date_month
data["Date_year"]=date_year

# %%
data.drop(columns=["Date"],inplace=True)

# %% [markdown]
# ### Analysis Starts here

# %%
data_topper = data.groupby("Student")["Points"].sum().sort_values(ascending=False)
data_topper.plot("bar")
data_topper
